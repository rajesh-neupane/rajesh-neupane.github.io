# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a TSV of publications with metadata and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)). The core python code is also in `publications.py`. Run either from the `markdown_generator` folder after replacing `publications.tsv` with one containing your data.
#
# TODO: Make this work with BibTex and other databases of citations, rather than Stuart's non-standard TSV format and citation style.

# %% [markdown]
# ## Data format
#
# The TSV needs to have the following columns: pub_date, title, venue, excerpt, citation, site_url, and paper_url, with a header at the top.
#
# - `excerpt` and `paper_url` can be blank, but the others must have values.
# - `pub_date` must be formatted as YYYY-MM-DD.
# - `url_slug` will be the descriptive part of the .md file and the permalink URL for the page about the paper. The .md file will be `YYYY-MM-DD-[url_slug].md` and the permalink will be `https://[yourdomain]/publications/YYYY-MM-DD-[url_slug]`
#
# This is how the raw file looks (it doesn't look pretty, use a spreadsheet or other program to edit and create).

# %%
# !cat publications.tsv
# Out:
# pub_date	title	venue	excerpt	citation	url_slug	paper_url	slides_url
# 2009-10-01	Paper Title Number 1	Journal 1	This paper is about the number 1. The number 2 is left for future work.	Your Name, You. (2009). "Paper Title Number 1." <i>Journal 1</i>. 1(1).	paper-title-number-1	http://academicpages.github.io/files/paper1.pdf	http://academicpages.github.io/files/slides1.pdf
# 2010-10-01	Paper Title Number 2	Journal 1	This paper is about the number 2. The number 3 is left for future work.	Your Name, You. (2010). "Paper Title Number 2." <i>Journal 1</i>. 1(2).	paper-title-number-2	http://academicpages.github.io/files/paper2.pdf	http://academicpages.github.io/files/slides2.pdf
# 2015-10-01	Paper Title Number 3	Journal 1	This paper is about the number 3. The number 4 is left for future work.	Your Name, You. (2015). "Paper Title Number 3." <i>Journal 1</i>. 1(3).	paper-title-number-3	http://academicpages.github.io/files/paper3.pdf	http://academicpages.github.io/files/slides3.pdf

# %% [markdown]
# ## Import pandas
#
# We are using the very handy pandas library for dataframes.

# %%
import pandas as pd

# %% [markdown]
# ## Import TSV
#
# Pandas makes this easy with the read_csv function. We are using a TSV, so we specify the separator as a tab, or `\t`.
#
# I found it important to put this data in a tab-separated values format, because there are a lot of commas in this kind of data and comma-separated values can get messed up. However, you can modify the import statement, as pandas also has read_excel(), read_json(), and others.

# %%
publications = pd.read_csv("/home/rajesh/work/portfolio/rajesh-neupane.github.io/markdown_generator/academic_citations.tsv", sep="\t", header=0)
publications
# Out:
#       pub_date                                              title  \
# 0   2024-10-01  Evaluating machine learning algorithms to pred...
# 1   2020-10-01  Antibiotic residue in marketed broiler meat of...
# 2   2020-10-01  Recent dynamics of poultry production in Nepal...
# 3          NaN  Non-antibiotic management of mastitis in dairy...
# 4          NaN                                Texas Dairy Matters
# 5          NaN                                        Tag: health
# 6   2022-10-01  Cystic urolithiasis in dogs: A case report and...
# 7   2019-10-01   Bacteriological quality of poultry meat in Nepal
# 8          NaN                                         Tag: dairy
# 9          NaN                                      Tag: medicine
# 10         NaN                                 Tag: organic-dairy
# 11         NaN                                      Tag: bacteria
# 12  2024-10-01  Cystic Urolithiasis in Dogs: A Case Report and...
# 13  2025-10-01  Evaluating the impact of milk sample-based pre...
# 14  2025-10-01  93. AI-driven quantification of heat stress in...
# 15  2025-10-01  44. Evaluating effects of heat stress on the e...
# 16  2025-10-01  134. Use computer vision to detect different d...
#
#                                           venue  excerpt  \
# 0                                      Plos one      NaN
# 1   Archives of Veterinary Science and Medicine      NaN
# 2                   Nepalese Veterinary Journal      NaN
# 3                   Texas A&M AgriLife Organic.      NaN
# 4                                           NaN      NaN
# 5                                           NaN      NaN
# 6     Veterinary Sciences: Research and Reviews      NaN
# 7                                 Int J Vet Sci      NaN
# 8                                           NaN      NaN
# 9                                           NaN      NaN
# 10                                          NaN      NaN
# 11                                          NaN      NaN
# 12                                          NaN      NaN
# 13                           JDS Communications      NaN
# 14                   Animal-Science proceedings      NaN
# 15                   Animal-Science proceedings      NaN
# 16                   Animal-Science proceedings      NaN
#
#                                              citation  \
# 0   Neupane, Rajesh, Aryal, Ashrant, Haeussermann,...
# 1   Maharjan, Bishal, Neupane, Rajesh, Bhatta, Dik...
# 2   Neupane, R, Kaphle, K,. (2020) "Recent dynamic...
# 3   Shrestha, Bhuwan, Neupane, Rajesh, Paudyal, Su...
# 4   Shrestha, Bhuwan, Neupane, Rajesh, Paudyal, Su...
# 5   Shrestha, Bhuwan, Neupane, Rajesh, Paudyal, Su...
# 6   Rana, C, Subedi, D, Kunwar, S, Neupane, R, Shr...
# 7   Neupane, R, Kaphle, K,. (2019) "Bacteriologica...
# 8   Shrestha, Bhuwan, Neupane, Rajesh, Paudyal, Su...
# 9   Shrestha, Bhuwan, Neupane, Rajesh, Paudyal, Su...
# 10  Shrestha, Bhuwan, Neupane, Rajesh, Paudyal, Su...
# 11  Shrestha, Bhuwan, Neupane, Rajesh, Paudyal, Su...
# 12  Rana, Chandrakala, Subedi, Deepak, Kunwar, Sha...
# 13  Paudyal, Sushil, Piñeiro, Juan M, Pilati, Artu...
# 14  Neupane, R, Shrestha, B, Rodriguez, N, Paudyal...
# 15  Neupane, R, Shrestha, B, Paudyal, S,. (2025) "...
# 16  Neupane, R, Pinedo, P, Paudyal, S,. (2025) "13...
#
#                                              url_slug  \
# 0   evaluating-machine-learning-algorithms-to-pred...
# 1   antibiotic-residue-in-marketed-broiler-meat-of...
# 2   recent-dynamics-of-poultry-production-in-nepal...
# 3   non-antibiotic-management-of-mastitis-in-dairy...
# 4                                 texas-dairy-matters
# 5                                          tag-health
# 6   cystic-urolithiasis-in-dogs-a-case-report-and-...
# 7    bacteriological-quality-of-poultry-meat-in-nepal
# 8                                           tag-dairy
# 9                                        tag-medicine
# 10                                  tag-organic-dairy
# 11                                       tag-bacteria
# 12  cystic-urolithiasis-in-dogs-a-case-report-and-...
# 13  evaluating-the-impact-of-milk-sample-based-pre...
# 14  93-ai-driven-quantification-of-heat-stress-in-...
# 15  44-evaluating-effects-of-heat-stress-on-the-ef...
# 16  134-use-computer-vision-to-detect-different-di...
#
#                   paper_url  slides_url
# 0                       NaN         NaN
# 1                       NaN         NaN
# 2                       NaN         NaN
# 3   https://agrilifeorganic         NaN
# 4                       NaN         NaN
# 5                       NaN         NaN
# 6                       NaN         NaN
# 7                       NaN         NaN
# 8                       NaN         NaN
# 9                       NaN         NaN
# 10                      NaN         NaN
# 11                      NaN         NaN
# 12                      NaN         NaN
# 13                      NaN         NaN
# 14                      NaN         NaN
# 15                      NaN         NaN
# 16                      NaN         NaN

# %%
publications= publications.dropna(subset=['pub_date'])

# %%
publications
# Out:
#       pub_date                                              title  \
# 0   2024-10-01  Evaluating machine learning algorithms to pred...
# 1   2020-10-01  Antibiotic residue in marketed broiler meat of...
# 2   2020-10-01  Recent dynamics of poultry production in Nepal...
# 6   2022-10-01  Cystic urolithiasis in dogs: A case report and...
# 7   2019-10-01   Bacteriological quality of poultry meat in Nepal
# 12  2024-10-01  Cystic Urolithiasis in Dogs: A Case Report and...
# 13  2025-10-01  Evaluating the impact of milk sample-based pre...
# 14  2025-10-01  93. AI-driven quantification of heat stress in...
# 15  2025-10-01  44. Evaluating effects of heat stress on the e...
# 16  2025-10-01  134. Use computer vision to detect different d...
#
#                                           venue  excerpt  \
# 0                                      Plos one      NaN
# 1   Archives of Veterinary Science and Medicine      NaN
# 2                   Nepalese Veterinary Journal      NaN
# 6     Veterinary Sciences: Research and Reviews      NaN
# 7                                 Int J Vet Sci      NaN
# 12                                          NaN      NaN
# 13                           JDS Communications      NaN
# 14                   Animal-Science proceedings      NaN
# 15                   Animal-Science proceedings      NaN
# 16                   Animal-Science proceedings      NaN
#
#                                              citation  \
# 0   Neupane, Rajesh, Aryal, Ashrant, Haeussermann,...
# 1   Maharjan, Bishal, Neupane, Rajesh, Bhatta, Dik...
# 2   Neupane, R, Kaphle, K,. (2020) "Recent dynamic...
# 6   Rana, C, Subedi, D, Kunwar, S, Neupane, R, Shr...
# 7   Neupane, R, Kaphle, K,. (2019) "Bacteriologica...
# 12  Rana, Chandrakala, Subedi, Deepak, Kunwar, Sha...
# 13  Paudyal, Sushil, Piñeiro, Juan M, Pilati, Artu...
# 14  Neupane, R, Shrestha, B, Rodriguez, N, Paudyal...
# 15  Neupane, R, Shrestha, B, Paudyal, S,. (2025) "...
# 16  Neupane, R, Pinedo, P, Paudyal, S,. (2025) "13...
#
#                                              url_slug paper_url  slides_url
# 0   evaluating-machine-learning-algorithms-to-pred...       NaN         NaN
# 1   antibiotic-residue-in-marketed-broiler-meat-of...       NaN         NaN
# 2   recent-dynamics-of-poultry-production-in-nepal...       NaN         NaN
# 6   cystic-urolithiasis-in-dogs-a-case-report-and-...       NaN         NaN
# 7    bacteriological-quality-of-poultry-meat-in-nepal       NaN         NaN
# 12  cystic-urolithiasis-in-dogs-a-case-report-and-...       NaN         NaN
# 13  evaluating-the-impact-of-milk-sample-based-pre...       NaN         NaN
# 14  93-ai-driven-quantification-of-heat-stress-in-...       NaN         NaN
# 15  44-evaluating-effects-of-heat-stress-on-the-ef...       NaN         NaN
# 16  134-use-computer-vision-to-detect-different-di...       NaN         NaN

# %% [markdown]
# ## Escape special characters
#
# YAML is very picky about how it takes a valid string, so we are replacing single and double quotes (and ampersands) with their HTML encoded equivilents. This makes them look not so readable in raw format, but they are parsed and rendered nicely.

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %% [markdown]
# ## Creating the markdown files
#
# This is where the heavy lifting is done. This loops through all the rows in the TSV dataframe, then starts to concatentate a big string (```md```) that contains the markdown for each type. It does the YAML metadata first, then does the description for the individual page.

# %%
import os
for row, item in publications.iterrows():
    
    md_filename = str(item.pub_date) + "-" + item.url_slug + ".md"
    html_filename = str(item.pub_date) + "-" + item.url_slug
    year = item.pub_date[:4]
    
    ## YAML variables
    
    md = "---\ntitle: \""   + item.title + '"\n'
    
    md += """collection: publications"""
    
    md += """\npermalink: /publication/""" + html_filename
    
    if len(str(item.excerpt)) > 5:
        md += "\nexcerpt: '" + html_escape(item.excerpt) + "'"
    
    md += "\ndate: " + str(item.pub_date) 
    
    md += "\nvenue: '" + html_escape(item.venue) + "'"
    
    if len(str(item.slides_url)) > 5:
        md += "\nslidesurl: '" + item.slides_url + "'"

    if len(str(item.paper_url)) > 5:
        md += "\npaperurl: '" + item.paper_url + "'"
    
    md += "\ncitation: '" + html_escape(item.citation) + "'"
    
    md += "\n---"
    
    ## Markdown description for individual page
        
    if len(str(item.excerpt)) > 5:
        md += "\n" + html_escape(item.excerpt) + "\n"

    if len(str(item.slides_url)) > 5:
        md += "\n[Download slides here](" + item.slides_url + ")\n" 

    if len(str(item.paper_url)) > 5:
        md += "\n[Download paper here](" + item.paper_url + ")\n" 
        
    md += "\nRecommended citation: " + item.citation
    
    md_filename = os.path.basename(md_filename)
       
    with open("../_publications/" + md_filename, 'w') as f:
        f.write(md)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 21
#      17     md += "\nexcerpt: '" + html_escape(item.excerpt) + "'"
#      19 md += "\ndate: " + str(item.pub_date)
# ---> 21 md += "\nvenue: '" + html_escape(item.venue) + "'"
#      23 if len(str(item.slides_url)) > 5:
#      24     md += "\nslidesurl: '" + item.slides_url + "'"
#
# Cell In[23], line 9, in html_escape(text)
#       7 def html_escape(text):
#       8     """Produce entities within text."""
# ----> 9     return "".join(html_escape_table.get(c,c) for c in text)
#
# TypeError: 'float' object is not iterable

# %% [markdown]
# These files are in the publications directory, one directory below where we're working from.

# %%
# !ls ../_publications/
# Out:
# 2009-10-01-paper-title-number-1.md
# 2010-10-01-paper-title-number-2.md
# 2015-10-01-paper-title-number-3.md
# 2019-10-01-bacteriological-quality-of-poultry-meat-in-nepal.md
# 2020-10-01-antibiotic-residue-in-marketed-broiler-meat-of-kathmandu-metropolitan-city.md
# 2020-10-01-recent-dynamics-of-poultry-production-in-nepal-food-security-to-sustainable-production.md
# 2022-10-01-cystic-urolithiasis-in-dogs-a-case-report-and-review-of-the-literature.md
# 2024-10-01-evaluating-machine-learning-algorithms-to-predict-lameness-in-dairy-cattle.md
# nan-non-antibiotic-management-of-mastitis-in-dairy-cattle.md

# %%
# !cat ../_publications/2009-10-01-paper-title-number-1.md
# Out:
# ---
# title: "Paper Title Number 1"
# collection: publications
# category: manuscripts
# permalink: /publication/2009-10-01-paper-title-number-1
# excerpt: 'This paper is about the number 1. The number 2 is left for future work.'
# date: 2009-10-01
# venue: 'Journal 1'
# slidesurl: 'http://academicpages.github.io/files/slides1.pdf'
# paperurl: 'http://academicpages.github.io/files/paper1.pdf'
# bibtexurl: 'http://academicpages.github.io/files/bibtex1.bib'
# citation: 'Your Name, You. (2009). &quot;Paper Title Number 1.&quot; <i>Journal 1</i>. 1(1).'
# ---
# The contents above will be part of a list of publications, if the user clicks the link for the publication than the contents of section will be rendered as a full page, allowing you to provide more information about the paper for the reader. When publications are displayed as a single page, the contents of the above "citation" field will automatically be included below this section in a smaller font.
